# %%
import numpy as np

from scipy.interpolate import interp1d,InterpolatedUnivariateSpline
from scipy.integrate import cumtrapz, quad
from scipy.special import erf

from WIMpy import DMUtils as DMU

from matplotlib import pyplot as plt
from matplotlib.ticker import LogLocator

from pylab import *

import matplotlib as mpl
from matplotlib import rc
rc('text', usetex=True)
rc('font',**{'family':'sans-serif','sans-serif':['cmr']})
rc('font',**{'family':'serif','serif':['cmr']})
rc('font', size=30)

mpl.rcParams['xtick.top'] = True
mpl.rcParams['ytick.right'] = True


import paleopy as paleopy

import swordfish as sf

import os.path

# %%
import scipy as sp
import scipy.interpolate

def log_interp1d(xx, yy, kind='linear'):
    logx = np.log10(xx)
    logy = np.log10(yy)
    lin_interp = sp.interpolate.interp1d(logx, logy, kind=kind, fill_value='extrapolate')
    log_interp = lambda zz: np.power(10.0, lin_interp(np.log10(zz)))
    return log_interp

# %%
colors = ['orangered', 'darkred', 'midnightblue', 'indigo', 'darkolivegreen', 'black']
colors = ['orangered', 'red', 'midnightblue', 'indigo', 'darkolivegreen', 'black']
colors = ['mediumblue', 'steelblue', 'darkorange', 'firebrick', 'forestgreen', 'springgreen', 'chocolate']
#colors = ['crimson', 'darkorange', 'darkmagenta', 'darkturquoise', 'black', 'darkgreen']
#colors = ['firebrick', 'darkorange', 'steelblue', 'chocolate', 'lightsteelblue', 'turquoise', 'lightseagreen']
linestyles = ['-', '-', '-', '-', '-', '-', '-']
labels = ['$\\upmu$ sea level', '$\\upmu$ from SN (20 $\\mathrm{pc}$)', '$\\upmu$ 1500 m.w.e.', '$\\upmu$ from SN (0 $\\mathrm{pc}$)','$^{238}\\text{U}$ spontaneous fission', 'Atmospheric neutrinos', 'Neutrons']
size = 2
font_size = 30

# %%
x_neut, flux_neut = np.loadtxt("./Data/Atmneutrino.txt", usecols = (0,1), delimiter=' ',  unpack='true')

Fneut = log_interp1d(x_neut*1e6, flux_neut/(x_neut*1e6)/1e3)

# %%
n_bins = 75
x_min = 0 #log scale in nm
x_max = 5.2 #log scale in nm

h_min = 0
h_max = 1e5
h_bins = 1000000


def loadSpectrum(mineral):
    x_bins = np.logspace(x_min,x_max,n_bins)
    x_width = np.diff(x_bins)
    x = x_bins[:-1] + x_width/2
    #Returns in events/kg/Myr/nm
    nu_list = ['DSNB', 'atm', 'hep', '8B', '15O', '17F', '13N', 'pep','pp','7Be-384','7Be-861', 'K', 'U', '235U', 'Th', '1987IA','CCSN']    
    E_list = np.logspace(-3, 3, 5000) # keV
    
    
    dRdx = []
    for j, nu_source in enumerate(nu_list):
        dRdx_temp = np.zeros_like(x)
        for i, nuc in enumerate(mineral.nuclei):
            if (nuc != "H"):
                xtemp = mineral.Etox_nuclei[nuc](E_list)
                dRdx_nuc = (np.vectorize(DMU.dRdE_CEvNS)(E_list, mineral.N_p[i], mineral.N_n[i], flux_name=nu_source)
                                                            *mineral.dEdx_nuclei[nuc](xtemp))
                temp_interp = interp1d(xtemp, dRdx_nuc, fill_value='extrapolate')
                dRdx_temp += mineral.ratio_nuclei[nuc]*temp_interp(x)
        dRdx.append(dRdx_temp*1e6*365+1e-20)
        
    solar = np.zeros(n_bins-1)
    dRdx.append(solar)
    
    #SOLAR NEUTRINOS
    for i in range(n_bins-1):
        for j in range(9):
            dRdx[17][i] += dRdx[j+2][i]
            
    geo = np.zeros(n_bins-1)
    dRdx.append(geo)
    
    #GEONEUTRINOS
    for i in range(n_bins-1):
        for j in range(4):
            dRdx[18][i] += dRdx[j+11][i]
    
    return dRdx

# %%
def plotSpectrum(mineral, dRdx, name, Ufrac, solar = False, geo = False, muonic = False, water = False):
    
    x_bins = np.logspace(x_min,x_max,n_bins)
    
    plt.figure(figsize=(13,8))
    
    '''
    for i in range(1):
        #Neutrino
        #plt.loglog(x_bins[:-1], dRdx[0],label=r'DSNB neutrinos')
        #plt.loglog(x_bins[:-1], dRdx[1],label=r'Atmospheric neutrinos')

        if(solar == True):
            plt.loglog(x_bins[:-1], dRdx[2],label=r'hep')
            plt.loglog(x_bins[:-1], dRdx[3],label=r'8B')
            plt.loglog(x_bins[:-1], dRdx[4],label=r'15O')
            plt.loglog(x_bins[:-1], dRdx[5],label=r'17F')
            plt.loglog(x_bins[:-1], dRdx[6],label=r'13N')
            plt.loglog(x_bins[:-1], dRdx[7],label=r'pep')
            plt.loglog(x_bins[:-1], dRdx[8],label=r'pp')
            plt.loglog(x_bins[:-1], dRdx[9],label=r'7Be-384')
            plt.loglog(x_bins[:-1], dRdx[10],label=r'7Be-861')
        else:
            #plt.loglog(x_bins[:-1], dRdx[17],label=r'Solar neutrinos')

        if(geo == True):    
            plt.loglog(x_bins[:-1], dRdx[11],label=r'K')
            plt.loglog(x_bins[:-1], dRdx[12],label=r'U')
            plt.loglog(x_bins[:-1], dRdx[13],label=r'235U')
            plt.loglog(x_bins[:-1], dRdx[14],label=r'Th') 
        else:
            #plt.loglog(x_bins[:-1], dRdx[18])
            #plt.loglog(x_bins[:-1], dRdx[18],label=r'Geo-neutrinos')

        #1987IA
        #plt.loglog(x_bins[:-1], dRdx[15]*mass,label=r'1987IA') 

        #CCSNe
        #plt.loglog(x_bins[:-1], dRdx[16],label=r'CCSNe neutrinos')   
        '''
    x_Th = mineral.xT_Thorium()
    x,y  = np.loadtxt("Data/"+name+"/"+name+"_fission.dat", usecols = (0,1), unpack='true')
    fiss = interp1d(x, y, fill_value='extrapolate')
    
    omega = 2*np.pi/3 # integral in theta, phi
    
    if(muonic):
        p1, = plt.loglog(x_bins[:-1], mineral.dRdx_muons(x_bins, 0), label=r'$\mu$ sea level ', linewidth = size, color = colors[0], linestyle = linestyles[0])
        p3, = plt.loglog(x_bins[:-1], mineral.dRdx_muons(x_bins, 6), label=r'$\mu$ 1500 m.w.e.', color = colors[2], linewidth = size, linestyle = linestyles[2])
        p2, = plt.loglog(x_bins[:-1], mineral.dRdx_muons(x_bins, 0)+mineral.dRdx_muons(x_bins, 7)/0.27, label=r'$\mu$ from SN (100 pc)', color = colors[3], linewidth = size, linestyle = linestyles[3])
        p4, = plt.loglog(x_bins[:-1], mineral.dRdx_muons(x_bins, 0)+mineral.dRdx_muons(x_bins, 8)/0.27, linestyle = linestyles[1], linewidth = size, color = colors[1], label=r'$\mu$ from SN (20 pc)')
        # p4, = plt.loglog(x_bins[:-1], mineral.dRdx_muons(x_bins, 9)/0.27, label=r'$\mu$ from SN (50 pc)', color = colors[3], linewidth = size, linestyle = linestyles[3])
        
        p3, = plt.loglog(x_bins[:-1], mineral.dRdx_muons(x_bins, 6), label=r'$\mu$ 1.5 km.w.e.', color = colors[2], linewidth = size, linestyle = linestyles[2])
        p2, = plt.loglog(x_bins[:-1], mineral.dRdx_muons(x_bins, "SN100pc_deep")/0.27, label=r'$\mu$ from SN (100 pc) 1.5 km.w.e.', color = colors[3], linewidth = size, linestyle = linestyles[3])
        p4, = plt.loglog(x_bins[:-1], mineral.dRdx_muons(x_bins, "SN20pc_deep")/0.27, linestyle = linestyles[1], linewidth = size, color = colors[1], label=r'$\mu$ from SN (20 pc) 1.5 km.w.e.')
    
    p5, = plt.loglog(x_bins[:-1], Ufrac*fiss(x_bins[:-1]),label=r'SFFs from $^{238}U$', color = colors[4], linewidth = size, linestyle = linestyles[4])
    p6, = plt.loglog(x_neut*1e6, flux_neut/(x_neut*1e6)/1e3, label=r'Atmospheric neutrinos', color = colors[5], linewidth = size, linestyle = linestyles[5])
    p7, = plt.loglog(x_bins[:-1], mineral.dRdx_neutrons(x_bins), label='Neutrons background', color = colors[6], linewidth = size, linestyle = linestyles[6])

    plt.legend(fontsize=22, loc = 'upper left',ncol=2)
    
    # l1 = legend([p3, p2, p4], ['SN 20 pc', 'SN 100 pc', 'SN 50 pc'], loc='upper right', bbox_to_anchor=(0.5, 1),title = r'$\textbf{Signal}$', fontsize = 23)

    l1 = legend([p1, p2, p4], ["Scenario A", 'Scenario B', 'Scenario C'], loc='upper right', bbox_to_anchor=(0.48, 1),title = r'$\textbf{Signal}$', fontsize = 23)
    l2 = legend([p3,p5,p6,p7], [labels[2], labels[4], labels[5], labels[6]], loc='upper left', bbox_to_anchor=(0.48, 1), fontsize = 23,title = r'$\textbf{Background}$')
    gca().add_artist(l1)

    ax = plt.gca()
    
    plt.ylabel(r"d$\textit{R}$/d$\textit{x}$ [$\mathrm{nm}^{-1}\,\mathrm{kg}^{-1}\,\mathrm{Myr}^{-1}$]",fontsize=font_size)
    plt.xlabel(r"$\textit{x}$ [$\mathrm{nm}$]",fontsize=font_size)
    plt.xlim(0.9*1e3,10.5*1e4)
    plt.ylim(2.1*1e-3,7.9*1e12)
    # plt.ylim(1e2,1e11)
    
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(2)
    
    ax.tick_params(axis = 'both', direction='in', length=9, width=2.5, which = 'major')
    ax.tick_params(axis = 'both', direction='in', length=5, width=1.5, which = 'minor')

    plt.savefig("dRdx_" + mineral.name + ".pdf",bbox_inches="tight")

    plt.show()

# %%
#print(mineral.dRdx_muons(x_bins, 0))
#print(mineral.dRdx_muons(x_bins, 7))
#print(mineral.dRdx_muons(x_bins, 7)/mineral.dRdx_muons(x_bins, 0))

# %%
rho   = 2.15 # g/cm3
mineralname = "Halite"
mineral = paleopy.Mineral("Halite", muon="true", water="true")
mineral.showProperties()
mineral.showSRIM()
# Out:
# Mineral name: Halite
#     N_nuclei: 2
#     Molar mass: 58.45  g/mol
#     nucleus 	*	 abun.  *	 (N_p, N_n)
#  **************************************************
#     Na		*	0.39349871685201027	*	(11.0, 12.0)
#     Cl		*	0.6065012831479898	*	(17.0, 18.45)
# Plotting SRIM data for Halite:

# %%
dRdx = []
dRdx = loadSpectrum(mineral)
# Out:
#  DMutils.py: Loading neutrino flux for the first time...
# Loading neutrino fluxes for...
#     DSNB
#     atm
#     hep
#     8B
#     15O
#     17F
#     pep
#     13N
#     pp
#     7Be-384
#     7Be-861
#     K
#     U
#     235U
#     Th
#     CNB
#     K1
#     U1
#     235U1
#     Th1
#     CCSN
#     SFR1b_0
#     SFR1b_1
#     prova
#     1987IA
# ...done.

# %%
x_bins = np.logspace(x_min,x_max,n_bins)
x_width = np.diff(x_bins)
x_mid = x_bins[:-1] + x_width/2

# %%
Ufrac = 5*1e4
plotSpectrum(mineral, dRdx, mineralname, Ufrac, "Halite", muonic = True)

# %%
def Integral(dRdx, x_bins):
    x_width_all = np.diff(x_bins)
    x_mid_all = x_bins[:-1] + x_width_all/2.
    
    dRdx_interp = interp1d(x_mid_all, dRdx, bounds_error=False, fill_value=0.0)
    A = []
    for i in range(len(x_bins)-1):
        A.append(quad(dRdx_interp,x_bins[i],x_bins[i+1])[0])
    return A

def IntegralTh(x_bins):
    x_Th = mineral.xT_Thorium()
    x = np.linspace(h_min,h_max,h_bins)
    
    A = []
    
    for i in range(len(x_bins)-1):
        if(x_Th>=x_bins[i] and x_bins[i+1]>x_Th):
            A.append(mineral.norm_Thorium(T=1e7))
        else: A.append(0)
        
    return A

def IntegralSSF(name,x_bins):
    x,y  = np.loadtxt("Data/"+name+"/"+name+"_fission.dat", usecols = (0,1), unpack='true')
    Ufrac = 5*1e4
    fiss = interp1d(x, Ufrac*y, fill_value='extrapolate')
    
    A = []
    for i in range(len(x_bins)-1):
        A.append(quad(fiss,x_bins[i],x_bins[i+1])[0])
    return A

# %%
DSNB = Integral(dRdx[0],x_bins)
Atm = Integral(dRdx[1],x_bins)
Solar = Integral(dRdx[17],x_bins)
Geo = Integral(dRdx[18],x_bins)
SSF = IntegralSSF('Halite',x_bins)
Th = IntegralTh(x_bins)

# %%
x_width_all = np.diff(x_bins)
x_mid_all = x_bins[:-1] + x_width_all/2.

Neut = []
muon = []
muon_SN100pc = []
muon_SN50pc = []
muon_deep = []
muon_SN20pc = []
Atm = []

dRdx_interp_neut = interp1d(x_mid_all, mineral.dRdx_neutrons(x_bins), bounds_error=False, fill_value=0.0)
dRdx_interp_muon = interp1d(x_mid_all, mineral.dRdx_muons(x_bins, 0), bounds_error=False, fill_value=0.0)
dRdx_interp_muon_deep = interp1d(x_mid_all, mineral.dRdx_muons(x_bins, 6), bounds_error=False, fill_value=0.0)
dRdx_interp_muon_SN20pc = interp1d(x_mid_all, mineral.dRdx_muons(x_bins, 7), bounds_error=False, fill_value=0.0)
dRdx_interp_muon_SN100pc = interp1d(x_mid_all, mineral.dRdx_muons(x_bins, 8), bounds_error=False, fill_value=0.0)
dRdx_interp_muon_SN50pc = interp1d(x_mid_all, mineral.dRdx_muons(x_bins, 9), bounds_error=False, fill_value=0.0)

for i in range(len(x_bins)-1):
    Neut.append(quad(dRdx_interp_neut,x_bins[i],x_bins[i+1])[0])
    muon.append(quad(dRdx_interp_muon,x_bins[i],x_bins[i+1])[0])
    muon_deep.append(quad(dRdx_interp_muon_deep,x_bins[i],x_bins[i+1])[0])
    muon_SN20pc.append(quad(dRdx_interp_muon_SN20pc,x_bins[i],x_bins[i+1])[0])
    muon_SN50pc.append(quad(dRdx_interp_muon_SN50pc,x_bins[i],x_bins[i+1])[0])
    muon_SN100pc.append(quad(dRdx_interp_muon_SN100pc,x_bins[i],x_bins[i+1])[0])
    Atm.append(quad(Fneut, x_bins[i], x_bins[i+1])[0])
    
Neut = np.array(Neut)
muon = np.array(muon)
muon_deep = np.array(muon_deep)
muon_SN20pc = np.array(muon_SN20pc)
muon_SN50pc = np.array(muon_SN50pc)
muon_SN100pc = np.array(muon_SN100pc)
Atm = np.array(Atm)

# %%
def plotInt(x_bins, mass, time):
    plt.figure(figsize=(13,8))
    #ax = fig.add_subplot(111)
    time1 = 0.64
    time1 = 0.27
    Ufrac = 5*1e4
    
    xx = np.array(x_bins[:-1]) + np.diff(x_bins)/2.
    
    Neut_hist = Neut*mass*time
    muon_hist = muon*mass*time1
    muon_deep_hist = muon_deep*mass*(time-time1)
    muon_SN20pc_hist = muon_SN20pc*mass
    muon_SN50pc_hist = muon_SN50pc*mass
    muon_SN100pc_hist = muon_SN100pc*mass
    Atm_hist =  Atm*mass*time1  
    
    X = []
    SSFhist = []
    
    for i in range(len(x_bins)-1):
        x = np.linspace(x_bins[i], x_bins[i+1]-0.001*x_bins[i], 100)
        for j in range(100):
            SSFhist.append(SSF[i]*mass*time)
            X.append(x[j])
    
    # labels = ['$\\upmu$ sea level', '$\\upmu$ sea level +' + "\n" +  '$\\upmu$ from SN (20 $\\mathrm{pc}$)', '$\\upmu$ sea level +' + "\n" +  '$\\upmu$ from SN (100 $\\mathrm{pc}$)', '$\\upmu$ 1500 m.w.e.', '$^{238}\\text{U}$ spontaneous fission', 'Atmospheric neutrinos', 'Neutrons']
    labels = ['$\\upmu$ sea level', '$\\upmu$ sea level +' + '$\\upmu$ from SN (20 $\\mathrm{pc}$)', '$\\upmu$ sea level +' +  '$\\upmu$ from SN (100 $\\mathrm{pc}$)', '$\\upmu$ 1500 m.w.e.', '$^{238}\\text{U}$ spontaneous fission', 'Atmospheric neutrinos', 'Neutrons']
    
    p5, = plt.loglog(X,SSFhist,label=r'$^{238}U$ spontaneous fission', color = [230./255.,159./255.,0.], linestyle = linestyles[4], linewidth = size)
    
    p1, = plt.step(xx,muon_hist, color = [0.,0.,0.], linestyle = linestyles[0], linewidth = size, where = 'mid' )
    p9, = plt.step(xx,muon_hist+muon_SN100pc_hist, color = [240./255.,228./255.,66./255.], linestyle = linestyles[0], linewidth = size, where = 'mid')
    p3, = plt.step(xx,muon_hist+muon_SN20pc_hist, color = [0.,114./255.,178./255.], linestyle = linestyles[0], linewidth = size, where = 'mid')
    
    # p5 = plt.fill_between(xx,muon_hist+0.1*muon_hist,muon_hist-0.1*muon_hist,color = [0.,0.,0.],alpha=0.6, step='mid')
    # p7 = plt.fill_between(xx,muon_hist+0.1*muon_hist+muon_SN20pc_hist+0.1*muon_SN20pc_hist,muon_hist-0.1*muon_hist+muon_SN20pc_hist-0.1*muon_SN20pc_hist,color = [0.,114./255.,178./255.],alpha=0.6, step='mid')
    # p10 = plt.fill_between(xx,muon_hist+0.1*muon_hist+muon_SN100pc_hist+0.1*muon_SN100pc_hist,muon_hist-0.1*muon_hist+muon_SN100pc_hist-0.1*muon_SN100pc_hist,color = [240./255.,228./255.,66./255.],alpha=0.6, step='mid')
    # p8  = plt.fill_between(X,np.array(muonhistgal)+np.array(muonhistgalerror),np.array(muonhistgal)-np.array(muonhistgalerror),color = colors[3],alpha=0.6)
    
    p4, = plt.step(xx,muon_deep_hist, color = [213./255.,94./255.,0.], linestyle = linestyles[4], linewidth = size, where='mid')
    
    p6, = plt.step(xx,Atm_hist, label=r'Atmospheric neutrinos', color = [0.,114./255.,178./255.], linestyle = linestyles[5], linewidth = size, where='mid')
    p7, = plt.step(xx,Neut_hist,label=r'Neutrons', color = [204./255,121./255.,167./255.], linestyle = linestyles[6], linewidth = size, where='mid')
    

    l1 = legend([p1, p3, p9], ["Scenario A", 'Scenario B', 'Scenario C'], loc='upper right', bbox_to_anchor=(0.67, 1.),title = r'$\textbf{Signal}$', fontsize = 23, frameon=False)
    # l1 = legend([p1, p3, p9], ["Scenario A", 'Scenario B', 'Scenario C'], loc='upper right', bbox_to_anchor=(0.48, 1.),title = r'$\textbf{Signal}$', fontsize = 23, frameon=False)
    # l2 = legend([p4, p5, p7], [labels[3], labels[4], labels[6]], loc='upper left', bbox_to_anchor=(0.48, 1.), fontsize = 23 ,title = r'$\textbf{Background}$', frameon=False)
    gca().add_artist(l1)

    ax = plt.gca()
    
    plt.ylim(0.5e2,0.9*1e4)
    plt.xlim(4*1e4,1.1*1e5)
    
    # plt.ylim(0.5e2,3e10)
    # plt.xlim(0.9e3, 1.1e5)
    
    plt.ylabel(r"$N$",fontsize=font_size)
    plt.xlabel(r"$x/\text{nm}$",fontsize=font_size)
    
    plt.xscale('log')
    plt.yscale('log')
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(2)
    
    ax.tick_params(axis = 'both', direction='in', length=9, width=2.5, which = 'both')
    ax.tick_params(axis = 'both', direction='in', length=5, width=1.5, which = 'minor')
    
    plt.savefig("Hist_" + mineral.name + "_MessianianoBottom.png", bbox_inches="tight", transparent=True)

# %%
mass = 0.01
time = 5.97
time = 5.60
x_bins = np.logspace(x_min,x_max,n_bins)
size = 3
font_size = 30

plotSpectrum(mineral, dRdx, mineralname, Ufrac, "Halite", muonic = True)
plotInt(x_bins, mass, time)

#FARE LA DISTANZA TRA IL MAGGIORE DELLE SUPERNOVE E IL FLUSSO ATTESO
